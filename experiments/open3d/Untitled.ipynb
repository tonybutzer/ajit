# %%
import numpy as np

# %%
import s3fs
import laspy

fs = s3fs.S3FileSystem()
with fs.open('my-bucket/some_file.las', 'rb') as f:
     if f.header.point_count < 100_000_000:
        las = laspy.read(f)

# %%
import laspy

# %%
import laspy
f = laspy.read("/home/ec2-user/data/ajit/HT404_1580305001_1264340300747572_1.las")
array = f.xyz

import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = [10, 10]
plt.rcParams["figure.autolayout"] = True
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(array[:100000, 0], array[:100000, 1], array[:100000, 1], c=array[:100000, 1], alpha=1)
plt.show()

# %%
array = f.xyz

# %%
array
# Out:
# array([[3.42331480e+05, 3.34089796e+06, 3.00500000e+01],
#        [3.42329160e+05, 3.34089509e+06, 2.99900000e+01],
#        [3.42331390e+05, 3.34089785e+06, 3.00400000e+01],
#        ...,
#        [3.42430160e+05, 3.34086084e+06, 3.08300000e+01],
#        [3.42443940e+05, 3.34088387e+06, 2.98600000e+01],
#        [3.42429760e+05, 3.34086085e+06, 3.15500000e+01]])

# %%
f.points.array[0]
# Out:
# (4233148, 4089796, 3005, 7, 9, 0, 17, 0, 0, 1.2643403e+15, 101, 95, 108)

# %%
dir(f.points)

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = [10, 10]
plt.rcParams["figure.autolayout"] = True
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(array[:200000, 0], array[:200000, 1], array[:200000, 1], c=array[:200000, 1], alpha=1)
plt.show()

# %%
dir(f)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_points',
#  '_write_to',
#  'add_extra_dim',
#  'add_extra_dims',
#  'change_scaling',
#  'evlrs',
#  'header',
#  'point_format',
#  'points',
#  'remove_extra_dim',
#  'remove_extra_dims',
#  'update_header',
#  'vlrs',
#  'write',
#  'xyz']

# %%
f.header.point_count
# Out:
# 4033409

# %%
list(f.point_format.dimension_names)
# Out:
# ['X',
#  'Y',
#  'Z',
#  'intensity',
#  'return_number',
#  'number_of_returns',
#  'scan_direction_flag',
#  'edge_of_flight_line',
#  'classification',
#  'synthetic',
#  'key_point',
#  'withheld',
#  'scan_angle_rank',
#  'user_data',
#  'point_source_id',
#  'gps_time',
#  'red',
#  'green',
#  'blue']

# %%
f.read()
# Out:
# <LasData(1.2, point fmt: <PointFormat(3, 0 bytes of extra dims)>, 4033409 points, 1 vlrs)>
