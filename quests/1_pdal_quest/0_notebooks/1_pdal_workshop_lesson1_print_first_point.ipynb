# %%
! conda list | grep pdal
# Out:
# # packages in environment at /home/ec2-user/miniconda3/envs/pdal_jupyter:
# pdal                      2.4.0                hec91d99_4    conda-forge
# pdal-plugins              1.2.0                    pypi_0    pypi
# python-pdal               3.1.2           py310h6245e14_1    conda-forge

# %%
! pdal info
# Out:
# PDAL: No input file specified.
#
# usage: pdal info [options] [input]
# standard options:
#   --developer-debug  Enable developer debug (don't trap exceptions)
#   --label            A string to label the process with
#   --driver           Override reader driver
#   --help             Print help and exit
# options:
#   --input, -i               Input file name
#   --all                     Dump statistics, schema and metadata
#   --point, -p               Point to dump --point="1-5,10,100-200" (0 indexed)
#   --query                   Return points in order of distance from the
#       specified location (2D or 3D) --query Xcoord,Ycoord[,Zcoord][/count]
#   --stats                   Dump stats on all points (reads entire dataset)
#   --boundary                Compute a hexagonal hull/boundary of dataset
#   --dimensions              Dimensions on which to compute statistics
#   --enumerate               Dimensions whose values should be enumerated
# ...

# %% [markdown]
# # Workshop STuff
# - https://pdal.io/workshop/exercises/index.html

# %%
! aws s3 ls eccoe-lidar/
# Out:
#                            PRE CO_Eastern_ElPaso_2018/
#                            PRE ajit/
#                            PRE las/
# 2022-02-25 20:40:59         44 readme.txt

# %%
! aws s3 ls eccoe-lidar/CO_Eastern_ElPaso_2018/
# Out:
# 2022-03-27 16:37:49   11449736 USGS_LPC_CO_EasternColorado_2018_A18_LD31201350.laz
# 2022-03-27 16:37:49   27172583 USGS_LPC_CO_EasternColorado_2018_A18_LD31201353.laz
# 2022-03-27 16:37:49   16713975 USGS_LPC_CO_EasternColorado_2018_A18_LD31201356.laz
# 2022-03-27 16:37:49   24014956 USGS_LPC_CO_EasternColorado_2018_A18_LD31201359.laz
# 2022-03-27 16:37:50   21893078 USGS_LPC_CO_EasternColorado_2018_A18_LD31201362.laz
# 2022-03-27 16:37:50   16514681 USGS_LPC_CO_EasternColorado_2018_A18_LD31201365.laz
# 2022-03-27 16:37:50   12999817 USGS_LPC_CO_EasternColorado_2018_A18_LD31201368.laz
# 2022-03-27 16:37:51    8293389 USGS_LPC_CO_EasternColorado_2018_A18_LD31201371.laz
# 2022-03-27 16:37:51    1287083 USGS_LPC_CO_EasternColorado_2018_A18_LD31201374.laz
# 2022-03-27 16:37:51   15866610 USGS_LPC_CO_EasternColorado_2018_A18_LD31231350.laz
# 2022-03-27 16:37:51   39067512 USGS_LPC_CO_EasternColorado_2018_A18_LD31231353.laz
# ...

# %%
# %%bash
#
# aws s3 cp s3://eccoe-lidar/CO_Eastern_ElPaso_2018/USGS_LPC_CO_EasternColorado_2018_A18_LD31201350.laz ~
# Out:
# download: s3://eccoe-lidar/CO_Eastern_ElPaso_2018/USGS_LPC_CO_EasternColorado_2018_A18_LD31201350.laz to ../../../../../../../../home/ec2-user/USGS_LPC_CO_EasternColorado_2018_A18_LD31201350.laz

# %%
! ls -l /home/ec2-user/USGS_LPC_CO_EasternColorado_2018_A18_LD31201350.laz
# Out:
# -rw-rw-r-- 1 ec2-user ec2-user 11449736 Mar 27 16:37 /home/ec2-user/USGS_LPC_CO_EasternColorado_2018_A18_LD31201350.laz

# %%
# pdal info ./exercises/info/interesting.las -p 0

# %%
! pdal info /home/ec2-user/USGS_LPC_CO_EasternColorado_2018_A18_LD31201350.laz -p 0
# Out:
# {
#   "file_size": 11449736,
#   "filename": "/home/ec2-user/USGS_LPC_CO_EasternColorado_2018_A18_LD31201350.laz",
#   "now": "2022-04-22T18:15:36+0000",
#   "pdal_version": "2.4.0 (git-version: 997a1c)",
#   "points":
#   {
#     "point":
#     {
#       "ClassFlags": 0,
#       "Classification": 1,
#       "EdgeOfFlightLine": 0,
#       "GpsTime": 215001970.7,
#       "Intensity": 1280,
#       "NumberOfReturns": 3,
#       "PointId": 0,
#       "PointSourceId": 1283,
#       "ReturnNumber": 1,
#       "ScanAngleRank": -4.782000065,
#       "ScanChannel": 0,
#       "ScanDirectionFlag": 0,
#       "UserData": 0,
#       "X": 3121871.315,
#       "Y": 1351901.555,
#       "Z": 11429.921
#     }
#   },
#   "reader": "readers.las"
# }

# %%
! pdal info --all /home/ec2-user/USGS_LPC_CO_EasternColorado_2018_A18_LD31201350.laz
# Out:
# {
#   "boundary":
#   {
#     "area": 11577110.97,
#     "avg_pt_per_sq_unit": 51.50138588,
#     "avg_pt_spacing": 3.782319462,
#     "boundary": "POLYGON ((3123206.38534872 1349589.14532376,3123873.92052308 1353057.75983812,3121871.315 1354213.96467624,3119201.17430256 1351901.555,3123206.38534872 1349589.14532376))",
#     "boundary_json": { "type": "Polygon", "coordinates": [ [ [ 3123206.38534872001037, 1349589.145323760109022 ], [ 3123873.920523080043495, 1353057.759838120080531 ], [ 3121871.315, 1354213.964676239993423 ], [ 3119201.174302559811622, 1351901.555 ], [ 3123206.38534872001037, 1349589.145323760109022 ] ] ] },
#     "density": 0.0699010316,
#     "edge_length": 0,
#     "estimated_edge": 2312.409676,
#     "hex_offsets": "MULTIPOINT (0 0, -667.535 1156.2, 0 2312.41, 1335.07 2312.41, 2002.61 1156.2, 1335.07 0)",
#     "sample_size": 5000,
#     "threshold": 15
#   },
#   "file_size": 11449736,
# ...

# %%
! pdal info --help
# Out:
# usage: pdal info [options] [input]
# standard options:
#   --developer-debug  Enable developer debug (don't trap exceptions)
#   --label            A string to label the process with
#   --driver           Override reader driver
#   --help             Print help and exit
# options:
#   --input, -i               Input file name
#   --all                     Dump statistics, schema and metadata
#   --point, -p               Point to dump --point="1-5,10,100-200" (0 indexed)
#   --query                   Return points in order of distance from the
#       specified location (2D or 3D) --query Xcoord,Ycoord[,Zcoord][/count]
#   --stats                   Dump stats on all points (reads entire dataset)
#   --boundary                Compute a hexagonal hull/boundary of dataset
#   --dimensions              Dimensions on which to compute statistics
#   --enumerate               Dimensions whose values should be enumerated
#   --schema                  Dump the schema
# ...

# %%
! pdal info --stats /home/ec2-user/USGS_LPC_CO_EasternColorado_2018_A18_LD31201350.laz
# Out:
# {
#   "file_size": 11449736,
#   "filename": "/home/ec2-user/USGS_LPC_CO_EasternColorado_2018_A18_LD31201350.laz",
#   "now": "2022-04-22T18:24:45+0000",
#   "pdal_version": "2.4.0 (git-version: 997a1c)",
#   "reader": "readers.las",
#   "stats":
#   {
#     "bbox":
#     {
#       "EPSG:4326":
#       {
#         "bbox":
#         {
#           "maxx": -105.0683947,
#           "maxy": 38.80180991,
#           "maxz": 3549.32779,
#           "minx": -105.0735521,
#           "miny": 38.79826988,
#           "minz": 3370.954449
#         },
#         "boundary": { "type": "Polygon", "coordinates": [ [ [ -105.073552081963371, 38.798288864625327, 3370.954449180283973 ], [ -105.073530959501483, 38.801809906631853, 3370.968886481337449 ], [ -105.068394654301272, 38.801790925117309, 3549.327790134110273 ], [ -105.068416031150122, 38.798269884045524, 3549.313437282704399 ], [ -105.073552081963371, 38.798288864625327, 3370.954449180283973 ] ] ] }
#       },
#       "native":
#       {
# ...

# %%
! pdal info --all /home/ec2-user/USGS_LPC_CO_EasternColorado_2018_A18_LD31201350.laz | grep -i epsg
# Out:
#     "comp_spatialreference": "COMPD_CS[\"NAD83(2011) / Colorado Central (ftUS) + NAVD88 height (ftUS) - US Geoid Model of 2012 B\",\n    PROJCS[\"NAD83(2011) / Colorado Central (ftUS)\",\n        GEOGCS[\"NAD83(2011)\",\n            DATUM[\"NAD83_National_Spatial_Reference_System_2011\",\n                SPHEROID[\"GRS 1980\",6378137,298.257222101,\n                    AUTHORITY[\"EPSG\",\"7019\"]],\n                AUTHORITY[\"EPSG\",\"1116\"]],\n            PRIMEM[\"Greenwich\",0,\n                AUTHORITY[\"EPSG\",\"8901\"]],\n            UNIT[\"degree\",0.0174532925199433,\n                AUTHORITY[\"EPSG\",\"9122\"]],\n            AUTHORITY[\"EPSG\",\"6318\"]],\n        PROJECTION[\"Lambert_Conformal_Conic_2SP\"],\n        PARAMETER[\"standard_parallel_1\",39.75],\n        PARAMETER[\"standard_parallel_2\",38.45],\n        PARAMETER[\"latitude_of_origin\",37.83333333333334],\n        PARAMETER[\"central_meridian\",-105.5],\n        PARAMETER[\"false_easting\",3000000],\n      
# ...

# %% [markdown]
# # https://epsg.io/6428
#
# - EPSG:6428
# - NAD83(2011) / Colorado Central (ftUS)

# %% [markdown]
# # Exercise - use proj4 to verify 4326 bounding box from EPSG:6428

# %%
! jsawk --help
# Out:
# /bin/bash: jsawk: command not found

# %%
! jq --help
# Out:
# jq - commandline JSON processor [version 1.5]
# Usage: jq [options] <jq filter> [file...]
#
# 	jq is a tool for processing JSON inputs, applying the
# 	given filter to its JSON text inputs and producing the
# 	filter's results as JSON on standard output.
# 	The simplest filter is ., which is the identity filter,
# 	copying jq's input to its output unmodified (except for
# 	formatting).
# 	For more advanced filters see the jq(1) manpage ("man jq")
# 	and/or https://stedolan.github.io/jq
#
# 	Some of the options include:
# 	 -c		compact instead of pretty-printed output;
# 	 -n		use `null` as the single input value;
# 	 -e		set the exit status code based on the output;
# 	 -s		read (slurp) all inputs into an array; apply filter to it;
# 	 -r		output raw strings, not JSON texts;
# 	 -R		read raw strings, not JSON texts;
# 	 -C		colorize JSON;
# 	 -M		monochrome (don't colorize JSON);
# 	 -S		sort keys of objects on output;
# 	 --tab	use tabs for indentation;
# ...

# %%
! pdal info --metadata /home/ec2-user/USGS_LPC_CO_EasternColorado_2018_A18_LD31201350.laz | jq ".metadata.compressed, .metadata.system_id"
# Out:
# true
# "LAStools (c) by rapidlasso GmbH"

# %%
# !pdal info /home/ec2-user/USGS_LPC_CO_EasternColorado_2018_A18_LD31201350.laz --metadata
# Out:
# {
#   "file_size": 11449736,
#   "filename": "/home/ec2-user/USGS_LPC_CO_EasternColorado_2018_A18_LD31201350.laz",
#   "metadata":
#   {
# ...

# %%
# !pdal info /home/ec2-user/USGS_LPC_CO_EasternColorado_2018_A18_LD31201350.laz --metadata | jq ".metadata.srs.wkt"
# Out:
# "PROJCS[\"NAD83(2011) / Colorado Central (ftUS)\",GEOGCS[\"NAD83(2011)\",DATUM[\"NAD83_National_Spatial_Reference_System_2011\",SPHEROID[\"GRS 1980\",6378137,298.257222101,AUTHORITY[\"EPSG\",\"7019\"]],AUTHORITY[\"EPSG\",\"1116\"]],PRIMEM[\"Greenwich\",0,AUTHORITY[\"EPSG\",\"8901\"]],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]],AUTHORITY[\"EPSG\",\"6318\"]],PROJECTION[\"Lambert_Conformal_Conic_2SP\"],PARAMETER[\"standard_parallel_1\",39.75],PARAMETER[\"standard_parallel_2\",38.45],PARAMETER[\"latitude_of_origin\",37.8333333333333],PARAMETER[\"central_meridian\",-105.5],PARAMETER[\"false_easting\",3000000],PARAMETER[\"false_northing\",1000000],UNIT[\"US survey foot\",0.304800609601219,AUTHORITY[\"EPSG\",\"9003\"]],AXIS[\"X\",EAST],AXIS[\"Y\",NORTH],AUTHORITY[\"EPSG\",\"6428\"]]"
