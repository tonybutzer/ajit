# %%
! pdal info /home/ec2-user/USGS_LPC_CO_EasternColorado_2018_A18_LD31201350.laz -p 0
# Out:
# {
#   "file_size": 11449736,
#   "filename": "/home/ec2-user/USGS_LPC_CO_EasternColorado_2018_A18_LD31201350.laz",
#   "now": "2022-04-29T19:51:03+0000",
#   "pdal_version": "2.4.0 (git-version: 997a1c)",
#   "points":
#   {
#     "point":
#     {
#       "ClassFlags": 0,
#       "Classification": 1,
#       "EdgeOfFlightLine": 0,
#       "GpsTime": 215001970.7,
#       "Intensity": 1280,
#       "NumberOfReturns": 3,
#       "PointId": 0,
#       "PointSourceId": 1283,
#       "ReturnNumber": 1,
#       "ScanAngleRank": -4.782000065,
#       "ScanChannel": 0,
#       "ScanDirectionFlag": 0,
#       "UserData": 0,
#       "X": 3121871.315,
#       "Y": 1351901.555,
#       "Z": 11429.921
#     }
#   },
#   "reader": "readers.las"
# }

# %%
# %%bash
# pdal tindex create --tindex ./boundary.sqlite --filespec /home/ec2-user/USGS_LPC_CO_EasternColorado_2018_A18_LD31201350.laz -f SQLite

# %%
# !ls -lh boundary.sqlite/
# Out:
# total 16K
# -rw-rw-r-- 1 ec2-user ec2-user 687 Apr 27 18:15 USGS_LPC_CO_EasternColorado_2018_A18_LD31201350.dbf
# -rw-rw-r-- 1 ec2-user ec2-user 145 Apr 27 18:15 USGS_LPC_CO_EasternColorado_2018_A18_LD31201350.prj
# -rw-rw-r-- 1 ec2-user ec2-user 236 Apr 27 18:15 USGS_LPC_CO_EasternColorado_2018_A18_LD31201350.shp
# -rw-rw-r-- 1 ec2-user ec2-user 108 Apr 27 18:15 USGS_LPC_CO_EasternColorado_2018_A18_LD31201350.shx

# %%
! tar cvf boundary.tar ./boundary.sqlite/
# Out:
# ./boundary.sqlite/
# ./boundary.sqlite/USGS_LPC_CO_EasternColorado_2018_A18_LD31201350.shp
# ./boundary.sqlite/USGS_LPC_CO_EasternColorado_2018_A18_LD31201350.shx
# ./boundary.sqlite/USGS_LPC_CO_EasternColorado_2018_A18_LD31201350.dbf
# ./boundary.sqlite/USGS_LPC_CO_EasternColorado_2018_A18_LD31201350.prj

# %%
! ls -lh *.tar
# Out:
# -rw-rw-r-- 1 ec2-user ec2-user 10K Apr 29 19:52 boundary.tar

# %% [markdown]
# ![what]("./qgis-colorado.JPG")

# %%
from IPython.display import Image
Image("qgis-colorado.JPG")
